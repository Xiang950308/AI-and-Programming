# %% [markdown]
# <a href="https://colab.research.google.com/github/Xiang950308/AI-and-Programming/blob/main/notebooks/01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook prepared by Mathieu Blondel.

# %% [markdown]
# # Welcome

# %% [markdown]
# Welcome to the first practical work of the week! In this practical, we will learn about the programming language Python as well as NumPy and Matplotlib, two fundamental tools for data science and machine learning in Python.

# %% [markdown]
# # Notebooks

# %% [markdown]
# This week, we will use Jupyter notebooks and Google colab as the primary way to practice machine learning. Notebooks are a great way to mix executable code with rich contents (HTML, images, equations written in LaTeX). Colab allows to run notebooks on the cloud for free without any prior installation, while leveraging the power of [GPUs](https://en.wikipedia.org/wiki/Graphics_processing_unit).

# %% [markdown]
# The document that you are reading is not a static web page, but an interactive environment called a notebook, that lets you write and execute code. Notebooks consist of so-called code cells, blocks of one or more Python instructions. For example, here is a code cell that stores the result of a computation (the number of seconds in a day) in a variable and prints its value:

# %%
# B11323225 廖宜翔
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Click on the "play" button to execute the cell. You should be able to see the result. Alternatively, you can also execute the cell by pressing Ctrl + Enter if you are on Windows / Linux or Command + Enter if you are on a Mac.

# %% [markdown]
# Variables that you defined in one cell can later be used in other cells:

# %%
# B11323225 廖宜翔
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Note that the order of execution is important. For instance, if we do not run the cell storing *seconds_in_a_day* beforehand, the above cell will raise an error, as it depends on this variable. To make sure that you run all the cells in the correct order, you can also click on "Runtime" in the top-level menu, then "Run all".

# %% [markdown]
# **Exercise.** Add a cell below this cell: click on this cell then click on "+ Code". In the new cell, compute the number of seconds in a year by reusing the variable *seconds_in_a_day*. Run the new cell.
#
# **練習**：在此儲存格下方新增一個儲存格：按一下此儲存格，然後按一下「+程式碼」。在新儲存格中，使用變數 *seconds_in_a_day* 計算一年中的秒數。運行新單元格。

# %%
# B11323225 廖宜翔
seconds_in_a_year = 365 * seconds_in_a_day
seconds_in_a_year
# Out:
# 31536000

# %% [markdown]
# # Python

# %% [markdown]
# Python is one of the most popular programming languages for machine learning, both in academia and in industry. As such, it is essential to learn this language for anyone interested in machine learning. In this section, we will review Python basics.

# %% [markdown]
# ## Arithmetic operations

# %% [markdown]
# Python supports the usual arithmetic operators: + (addition), * (multiplication), / (division), ** (power), // (integer division).
#
# Python 支援常用的算術運算子：+（加法）、*（乘法）、/（除法）、**（冪）、//（整數除法）。

# %% [markdown]
# ## Lists

# %% [markdown]
# Lists are a container type for ordered sequences of elements. Lists can be initialized empty
#
# 列表是一種用於儲存有序元素序列的容器類型。列表可以初始化為空。

# %%
# B11323225 廖宜翔
my_list = []

# %% [markdown]
# or with some initial elements
#
# 或帶有一些初始元素

# %%
# B11323225 廖宜翔
my_list = [1, 2, 3]

# %% [markdown]
# Lists have a dynamic size and elements can be added (appended) to them
#
# 清單的大小是動態的，可以向其中添加（追加）元素。

# %%
# B11323225 廖宜翔
my_list.append(4)
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# We can access individual elements of a list (indexing starts from 0)
#
# 我們可以存取清單中的各個元素（索引從0開始）。

# %%
# B11323225 廖宜翔
my_list[2]
# Out:
# 3

# %% [markdown]
# We can access "slices" of a list using `my_list[i:j]` where `i` is the start of the slice (again, indexing starts from 0) and `j` the end of the slice. For instance:
#
# 我們可以使用 `my_list[i:j]` 存取清單的“切片”，其中 `i` 是切片的起始位置（索引從 0 開始），`j` 是切片的結束位置。例如：

# %%
# B11323225 廖宜翔
my_list[1:3]
# Out:
# [2, 3]

# %% [markdown]
# Omitting the second index means that the slice shoud run until the end of the list
#
# 省略第二個索引意味著切片操作應該一直執行到清單末尾。

# %%
# B11323225 廖宜翔
my_list[1:]
# Out:
# [2, 3, 4]

# %% [markdown]
# We can check if an element is in the list using `in`
#
# 我們可以使用 `in` 來檢查一個元素是否在清單中。

# %%
# B11323225 廖宜翔
5 in my_list
# Out:
# False

# %% [markdown]
# The length of a list can be obtained using the `len` function
#
# 可以使用 `len` 函數來取得列表的長度。

# %%
# B11323225 廖宜翔
len(my_list)
# Out:
# 4

# %% [markdown]
# ## Strings

# %% [markdown]
# Strings are used to store text. They can delimited using either single quotes or double quotes
#
# 字串用於存儲文字。它們可以用單引號或雙引號分隔。

# %%
# B11323225 廖宜翔
string1 = "some text"
string2 = 'some other text'

# %% [markdown]
# Strings behave similarly to lists. As such we can access individual elements in exactly the same way
#
# 字串的行為與列表類似。因此，我們可以用完全相同的方式存取單一元素。

# %%
# B11323225 廖宜翔
string1[3]
# Out:
# 'e'

# %% [markdown]
# and similarly for slices
#
# 切片的情況也類似。

# %%
# B11323225 廖宜翔
string1[5:]
# Out:
# 'text'

# %% [markdown]
# String concatenation is performed using the `+` operator
#
# 字串連線使用 `+` 運算子執行。

# %%
# B11323225 廖宜翔
string1 + " " + string2
# Out:
# 'some text some other text'

# %% [markdown]
# ## Conditionals

# %% [markdown]
# As their name indicates, conditionals are a way to execute code depending on whether a condition is True or False. As in other languages, Python supports `if` and `else` but `else if` is contracted into `elif`, as the example below demonstrates.
#
# 顧名思義，條件語句是一種根據條件是真還是假來執行程式碼的方法。與其他語言一樣，Python 支援 `if` 和 `else` 語句，但 `else if` 會被縮寫​​為 `elif`，如下例所示。

# %%
# B11323225 廖宜翔
my_variable = 5
if my_variable < 0:
  print("negative")
elif my_variable == 0:
  print("null")
else: # my_variable > 0
  print("positive")
# Out:
# positive

# %% [markdown]
# Here `<` and `>` are the strict `less` and `greater than` operators, while `==` is the equality operator (not to be confused with `=`, the variable assignment operator). The operators `<=` and `>=` can be used for less (resp. greater) than or equal comparisons.
#
# 這裡，`<` 和 `>` 分別是嚴格的「小於」和「大於」運算符，而 `==` 是相等運算子（不要與變數賦值運算子 `=` 混淆）。運算符 `<=` 和 `>=` 可以用於小於（或大於）或等於的比較。

# %% [markdown]
# Contrary to other languages, blocks of code are delimited using indentation. Here, we use 2-space indentation but many programmers also use 4-space indentation. Any one is fine as long as you are consistent throughout your code.
#
# 與其他語言不同，程式碼區塊之間使用縮排分隔。這裡我們使用 2 個空格的縮排，但許多程式設計師也使用 4 個空格的縮排。只要程式碼中保持一致，兩種縮排方式都可以。

# %% [markdown]
# ## Loops

# %% [markdown]
# Loops are a way to execute a block of code multiple times. There are two main types of loops: while loops and for loops.
#
# 迴圈是一種多次執行一段程式碼的方法。迴圈主要有兩種：while 迴圈和 for 迴圈。

# %% [markdown]
# While loop

# %%
# B11323225 廖宜翔
i = 0
while i < len(my_list):
  print(my_list[i])
  i += 1 # equivalent to i = i + 1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# For loop

# %%
# B11323225 廖宜翔
for i in range(len(my_list)):
  print(my_list[i])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# If the goal is simply to iterate over a list, we can do so directly as follows
#
# 如果目標只是遍歷一個列表，我們可以直接這樣做，如下所示。

# %%
# B11323225 廖宜翔
for element in my_list:
  print(element)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Functions

# %% [markdown]
# To improve code readability, it is common to separate the code into different blocks, responsible for performing precise actions: functions. A function takes some inputs and process them to return some outputs.
#
# 為了提高程式碼可讀性，通常將程式碼拆分成不同的程式碼區塊，每個程式碼區塊負責執行特定的操作：函數。函數接收一些輸入，並對其進行處理，最終會傳回一些輸出。

# %%
# B11323225 廖宜翔
def square(x):
  return x ** 2

def multiply(a, b):
  return a * b

# Functions can be composed.
square(multiply(3, 2))
# Out:
# 36

# %% [markdown]
# To improve code readability, it is sometimes useful to explicitly name the arguments
#
# 為了提高程式碼可讀性，有時明確地命名參數會很有幫助。

# %%
# B11323225 廖宜翔
square(multiply(a=3, b=2))
# Out:
# 36

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Using a conditional, write the [relu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)) function defined as follows
#
# **練習 1.** 使用條件語句，寫出如下定義的 [relu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)) 函數：
#
# $\text{relu}(x) = \left\{
#    \begin{array}{rl}
#      x, & \text{if }  x \ge 0 \\
#      0, & \text{otherwise }.
#    \end{array}\right.$

# %%
# B11323225 廖宜翔
def relu(x):
  if x>=0:
    return x
  else:
    return 0

relu(-3)
# Out:
# 0

# %% [markdown]
# **Exercise 2.** Using a foor loop, write a function that computes the [Euclidean norm](https://en.wikipedia.org/wiki/Norm_(mathematics)#Euclidean_norm) of a vector, represented as a list.
#
# **練習 2.** 使用 for 迴圈寫函數，計算以列表形式表示的向量的[歐幾里德範數](https://en.wikipedia.org/wiki/Norm_(mathematics)#Euclidean_norm)。

# %%
# B11323225 廖宜翔
def euclidean_norm(vector):
  sum_of_squares = 0
  for x in vector:
    sum_of_squares += x**2
  return sum_of_squares**0.5

import numpy as np
my_vector = [0.5, -1.2, 3.3, 4.5]

# The result should be roughly 5.729746940310715
euclidean_norm(my_vector)
# Out:
# 5.729746940310715

# %% [markdown]
# **Exercise 3.** Using a for loop and a conditional, write a function that returns the maximum value in a vector.
#
# **練習 3.** 使用 for 迴圈和條件語句，寫一個函數，回傳向量中的最大值。

# %%
# B11323225 廖宜翔
def vector_maximum(vector):
  if not vector:
        return None

  max_val = vector[0]

  for x in vector:
    if x > max_val:
      max_val = x
  return max_val

my_vector = [0.5, -1.2, 3.3, 4.5, 2.1]
print(f"向量 {my_vector} 中的最大值是: {vector_maximum(my_vector)}")
# Out:
# 向量 [0.5, -1.2, 3.3, 4.5, 2.1] 中的最大值是: 4.5

# %% [markdown]
# **Bonus exercise.** if time permits, write a function that sorts a list in ascending order (from smaller to bigger) using the [bubble sort](https://en.wikipedia.org/wiki/Bubble_sort) algorithm.
#
# **附加練習**： 如果時間允許，請寫一個函數，使用[泡沫排序](https://en.wikipedia.org/wiki/Bubble_sort)演算法對清單進行升序排序（從小到大）。

# %%
# B11323225 廖宜翔
def bubble_sort(my_list):
  n = len(my_list)
  for i in range(n):
    for j in range(0, n - i - 1):
      if my_list[j] > my_list[j+1]:
        my_list[j], my_list[j+1] = my_list[j+1], my_list[j]
  return my_list

my_list = [1, -3, 3, 2]
# Should return [-3, 1, 2, 3]
bubble_sort(my_list)
# Out:
# [-3, 1, 2, 3]

# %% [markdown]
# ## Going further

# %% [markdown]
# Clearly, it is impossible to cover all the language features in this short introduction. To go further, we recommend the following resources:

# %% [markdown]
# *   List of Python [tutorials](https://wiki.python.org/moin/BeginnersGuide/Programmers)
# * Four-hour [course](https://www.youtube.com/watch?v=rfscVS0vtbw) on Youtube

# %% [markdown]
# # NumPy

# %% [markdown]
# NumPy is a popular library for storing arrays of numbers and performing computations on them. Not only this enables to write often more succint code, this also makes the code faster, since most NumPy routines are implemented in C for speed.
#
# NumPy 是一個流行的庫，用於儲存數字數組並對其進行計算。這不僅能夠編寫更簡潔的程式碼，還能提高程式碼運行速度，因為大多數 NumPy 例程都是用 C 語言實現的，以提高速度。

# %% [markdown]
# To use NumPy in your program, you need to import it as follows
#
# 要在程式中使用 NumPy，需要如下匯入它：

# %%
# B11323225 廖宜翔
import numpy as np

# %% [markdown]
# ## Array creation

# %% [markdown]
# NumPy arrays can be created from Python lists
#
# 可以從 Python 列表建立 NumPy 陣列

# %%
# B11323225 廖宜翔
my_array = np.array([1, 2, 3])
my_array
# Out:
# array([1, 2, 3])

# %% [markdown]
# NumPy supports array of arbitrary dimension. For example, we can create two-dimensional arrays (e.g. to store a matrix) as follows
#
# NumPy 支援任意維度的陣列。例如，我們可以如下建立二維數組（例如：用於儲存矩陣）。

# %%
# B11323225 廖宜翔
my_2d_array = np.array([[1, 2, 3], [4, 5, 6]])
my_2d_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# We can access individual elements of a 2d-array using two indices
#
# 我們可以使用兩個索引來存取二維數組的各個元素。

# %%
# B11323225 廖宜翔
my_2d_array[1, 2]
# Out:
# np.int64(6)

# %% [markdown]
# We can also access rows
#
# 我們還可以訪問行

# %%
# B11323225 廖宜翔
my_2d_array[1]
# Out:
# array([4, 5, 6])

# %% [markdown]
# and columns
#
# 和列

# %%
# B11323225 廖宜翔
my_2d_array[:, 2]
# Out:
# array([3, 6])

# %% [markdown]
# Arrays have a `shape` attribute
#
# 數組具有 `形狀` 屬性

# %%
# B11323225 廖宜翔
print(my_array.shape)
print(my_2d_array.shape)
# Out:
# (3,)
# (2, 3)

# %% [markdown]
# Contrary to Python lists, NumPy arrays must have a type and all elements of the array must have the same type.
#
# 與 Python 列表不同，NumPy 陣列必須具有類型，且陣列中的所有元素必須具有相同的類型。

# %%
# B11323225 廖宜翔
my_array.dtype
# Out:
# dtype('int64')

# %% [markdown]
# The main types are `int32` (32-bit integers), `int64` (64-bit integers), `float32` (32-bit real values) and `float64` (64-bit real values).
#
# 主要型別有 `int32`（32 位元整數）、`int64`（64 位元整數）、`float32`（32 位元實數）和 `float64`（64 位元實數）。

# %% [markdown]
# The `dtype` can be specified when creating the array
#
# 建立陣列時可以指定 `資料類型` 參數。

# %%
# B11323225 廖宜翔
my_array = np.array([1, 2, 3], dtype=np.float64)
my_array.dtype
# Out:
# dtype('float64')

# %% [markdown]
# We can create arrays of all zeros using
#
# 我們可以使用以下方法建立全零數組：

# %%
# B11323225 廖宜翔
zero_array = np.zeros((2, 3))
zero_array
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# and similarly for all ones using `ones` instead of `zeros`.
#
# 類似地，對於所有使用 `ones` 而不是 `zeros` 的 1 來說也是如此。

# %% [markdown]
# We can create a range of values using
#
# 我們可以使用以下方式建立一系列值

# %%
# B11323225 廖宜翔
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# or specifying the starting point
#
# 或指定起點

# %%
# B11323225 廖宜翔
np.arange(3, 5)
# Out:
# array([3, 4])

# %% [markdown]
# Another useful routine is `linspace` for creating linearly spaced values in an interval. For instance, to create 10 values in `[0, 1]`, we can use
#
# 另一個有用的例程是 `linspace`，用於在區間內建立線性間隔的值。例如，要在 `[0, 1]` 中建立 10 個值，我們可以使用

# %%
# B11323225 廖宜翔
np.linspace(0, 1, 10)
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %% [markdown]
# Another important operation is `reshape`, for changing the shape of an array
#
# 另一個重要的操作是 `reshape`，用來改變陣列的形狀。

# %%
# B11323225 廖宜翔
my_array = np.array([1, 2, 3, 4, 5, 6])
my_array.reshape(3, 2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# Play with these operations and make sure you understand them well.

# %% [markdown]
# ## Basic operations

# %% [markdown]
# In NumPy, we express computations directly over arrays. This makes the code much more succint.
#
# 在 NumPy 中，我們直接對數組進行計算。這使得程式碼更加簡潔。

# %% [markdown]
# Arithmetic operations can be performed directly over arrays. For instance, assuming two arrays have a compatible shape, we can add them as follows
#
# 可以直接對數組進行算術運算。例如，假設兩個陣列的形狀相容，我們可以如下將它們相加：

# %%
# B11323225 廖宜翔
array_a = np.array([1, 2, 3])
array_b = np.array([4, 5, 6])
array_a + array_b
# Out:
# array([5, 7, 9])

# %% [markdown]
# Compare this with the equivalent computation using a for loop
#
# 將此與使用 for 迴圈的等效計算進行比較

# %%
# B11323225 廖宜翔
array_out = np.zeros_like(array_a)
for i in range(len(array_a)):
  array_out[i] = array_a[i] + array_b[i]
array_out
# Out:
# array([5, 7, 9])

# %% [markdown]
# Not only this code is more verbose, it will also run much more slowly.
#
# 這段程式碼不僅更加冗長，而且運行速度也會慢得多。

# %% [markdown]
# In NumPy, functions that operates on arrays in an element-wise fashion are called [universal functions](https://numpy.org/doc/stable/reference/ufuncs.html). For instance, this is the case of `np.sin`
#
# 在 NumPy 中，逐元素操作陣列的函數稱為通用函數 [universal functions](https://numpy.org/doc/stable/reference/ufuncs.html)。例如，`np.sin` 就是通用函數。

# %%
# B11323225 廖宜翔
np.sin(array_a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %% [markdown]
# Vector inner product can be performed using `np.dot`
#
# 可以使用 `np.dot` 執行向量內積。

# %%
# B11323225 廖宜翔
np.dot(array_a, array_b)
# Out:
# np.int64(32)

# %% [markdown]
# When the two arguments to `np.dot` are both 2d arrays, `np.dot` becomes matrix multiplication
#
# 向量內積可以使用 `np.dot` 實作。當 `np.dot` 的兩個參數都是二維陣列時，`np.dot` 就變成了矩陣乘法。

# %%
# B11323225 廖宜翔
array_A = np.random.rand(5, 3)
array_B = np.random.randn(3, 4)
np.dot(array_A, array_B)
# Out:
# array([[-0.45229082, -0.50489695,  0.44762363,  0.82681914],
#        [-0.86257863, -2.76750585,  1.21982721,  0.42284486],
#        [-0.47982565, -1.38546065,  1.20932075,  0.92239681],
#        [-0.34298351, -1.50678043,  1.68460182,  1.07841692],
#        [-0.42744086, -1.72278698,  1.78167825,  1.14323013]])

# %% [markdown]
# Matrix transpose can be done using `.transpose()` or `.T` for short
#
# 矩陣轉置可以使用 `.transpose()` 或簡寫為 `.T` 來實現。

# %%
# B11323225 廖宜翔
array_A.T
# Out:
# array([[0.2245424 , 0.72479619, 0.62860735, 0.85336319, 0.91029671],
#        [0.02830964, 0.94189898, 0.2722376 , 0.22475968, 0.29344651],
#        [0.53706266, 0.47961398, 0.53633412, 0.51143765, 0.57053924]])

# %% [markdown]
# ## Slicing and masking

# %% [markdown]
# Like Python lists, NumPy arrays support slicing
#
# 與 Python 列表類似，NumPy 數組也支援切片。

# %%
# B11323225 廖宜翔
np.arange(10)[5:]
# Out:
# array([5, 6, 7, 8, 9])

# %% [markdown]
# We can also select only certain elements from the array
#
# 我們也可以只從陣列中選擇某些元素。

# %%
# B11323225 廖宜翔
x = np.arange(10)
mask = x >= 5
x[mask]
# Out:
# array([5, 6, 7, 8, 9])

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Create a 3d array of shape (2, 2, 2), containing 8 values. Access individual elements and slices.
#
# **練習 1**： 建立一個形狀為 (2, 2, 2) 的三維數組，包含 8 個值。訪問各個元素和切片。

# %%
# B11323225 廖宜翔
import numpy as np
my_3d_array = np.array([
    [[0, 1], [2, 3]],
    [[4, 5], [6, 7]]])
print("原始3D陣列：")
print(my_3d_array)
print("-" * 20)


val_1 = my_3d_array[0, 1, 1]
val_2 = my_3d_array[1, 0, 0]
print(f"存取元素[0, 1, 1]: {val_1}")
print(f"存取元素[1, 0, 0]: {val_2}")
print("-" * 20)


slice_layer_0 = my_3d_array[0, :, :]


slice_all_col_0 = my_3d_array[:, :, 0]
print("第一層所有內容：")
print(slice_layer_0)
print("\n所有層的第0列數據：")
print(slice_all_col_0)
# Out:
# 原始3D陣列：
# [[[0 1]
#   [2 3]]
#
#  [[4 5]
#   [6 7]]]
# --------------------
# 存取元素[0, 1, 1]: 3
# 存取元素[1, 0, 0]: 4
# --------------------
# 第一層所有內容：
# [[0 1]
#  [2 3]]
#
# 所有層的第0列數據：
# [[0 2]
#  [4 6]]

# %% [markdown]
# **Exercise 2.** Rewrite the relu function (see Python section) using [np.maximum](https://numpy.org/doc/stable/reference/generated/numpy.maximum.html). Check that it works on both a single value and on an array of values.
#
# **練習 2**： 使用 [np.maximum](https://numpy.org/doc/stable/reference/generated/numpy.maximum.html) 重寫 relu 函數（請參閱 Python 部分）。檢查它是否能處理單一值和值數組。

# %%
# B11323225 廖宜翔
import numpy as np
def relu_numpy(x):
    return np.maximum(0, x)

relu_numpy(np.array([1, -3, 2.5]))
# Out:
# array([1. , 0. , 2.5])

# %% [markdown]
# **Exercise 3.** Rewrite the Euclidean norm of a vector (1d array) using NumPy (without for loop)
#
# **練習 3**： 使用 NumPy 重寫向量（一維數組）的歐幾里德範數（不使用 for 迴圈）。

# %%
# B11323225 廖宜翔
def euclidean_norm_numpy(x):
  return np.linalg.norm(x)

my_vector = np.array([0.5, -1.2, 3.3, 4.5])
euclidean_norm_numpy(my_vector)
# Out:
# np.float64(5.729746940310715)

# %% [markdown]
# **Exercise 4.** Write a function that computes the Euclidean norms of a matrix (2d array) in a row-wise fashion. Hint: use the `axis` argument of [np.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html).
#
# **練習 4**： 寫一個函數，按行計算矩陣（二維數組）的歐幾里德範數。提示：使用 [np.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html) 的 `axis` 參數。

# %%
# B11323225 廖宜翔
import numpy as np
def euclidean_norm_2d(X):
  return np.sum(X**2, axis=1)**0.5

my_matrix = np.array([[0.5, -1.2, 4.5],
            [-3.2, 1.9, 2.7]])

# Should return an array of size 2.
euclidean_norm_2d(my_matrix)
# Out:
# array([4.68401537, 4.59782557])

# %% [markdown]
# **Exercise 5.** Compute the mean value of the features in the [iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html). Hint: use the `axis` argument on [np.mean](https://numpy.org/doc/stable/reference/generated/numpy.mean.html).
#
# **練習 5**： 計算 [iris 資料集](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html) 中各特徵的平均值。提示：使用 [np.mean](https://numpy.org/doc/stable/reference/generated/numpy.mean.html) 的 `axis` 參數。

# %%
# B11323225 廖宜翔
import numpy as np
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)
feature_means = np.mean(X, axis=0)

print(f"資料集形狀 (Samples, Features): {X.shape}")
print(f"四個特徵的平均值分別為: {feature_means}")
print(f"結果陣列的大小: {feature_means.shape}")
# Out:
# 資料集形狀 (Samples, Features): (150, 4)
# 四個特徵的平均值分別為: [5.84333333 3.05733333 3.758      1.19933333]
# 結果陣列的大小: (4,)

# %% [markdown]
# ## Going further

# %% [markdown]
# * NumPy [reference](https://numpy.org/doc/stable/reference/)
# * SciPy [lectures](https://scipy-lectures.org/)
# *   One-hour [tutorial](https://www.youtube.com/watch?v=QUT1VHiLmmI) on Youtube

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Basic plots

# %% [markdown]
# Matplotlib is a plotting library for Python.
#
# Matplotlib 是一個用於 Python 的繪圖函式庫。

# %% [markdown]
# We start with a rudimentary plotting example.
#
# 我們先來看一個簡單的繪圖範例。

# %%
# B11323225 廖宜翔
from matplotlib import pyplot as plt

x_values = np.linspace(-3, 3, 100)

plt.figure()
plt.plot(x_values, np.sin(x_values), label="Sinusoid")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Matplotlib example")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# We continue with a rudimentary scatter plot example. This example displays samples from the [iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html) using the first two features. Colors indicate class membership (there are 3 classes).
#
# 我們繼續來看一個簡單的散點圖範例。此範例展示了使用前兩個特徵從[iris資料集](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html)中採集的樣本。顏色表示類別（共有3個類別）。

# %%
# B11323225 廖宜翔
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)

X_class0 = X[y == 0]
X_class1 = X[y == 1]
X_class2 = X[y == 2]

plt.figure()
plt.scatter(X_class0[:, 0], X_class0[:, 1], label="Class 0", color="C0")
plt.scatter(X_class1[:, 0], X_class1[:, 1], label="Class 1", color="C1")
plt.scatter(X_class2[:, 0], X_class2[:, 1], label="Class 2", color="C2")
plt.show()

# %% [markdown]
# We see that samples belonging to class 0 can be linearly separated from the rest using only the first two features.
#
# 我們可以看到，僅使用前兩個特徵就可以將屬於第 0 類的樣本與其他樣本線性區分開來。

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Plot the relu and the [softplus](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)#Softplus) functions on the same graph.
#
# **練習 1**： 在同一張圖上繪製 relu 函式和 [softplus](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)#Softplus) 函式。

# %%
# B11323225 廖宜翔
import numpy as np
import matplotlib.pyplot as plt
def plot_activation_functions():
    x = np.linspace(-5, 5, 500)
    y_relu = np.maximum(0, x)
    y_softplus = np.log(1 + np.exp(x))
    plt.figure(figsize=(8, 5))
    plt.plot(x, y_relu, label='ReLU', color='blue', linestyle='--', linewidth=2)
    plt.plot(x, y_softplus, label='Softplus', color='red', linewidth=2)
    plt.title('Comparison of ReLU and Softplus Functions')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.show()

plot_activation_functions()

# %% [markdown]
# What is the main difference between the two functions?
#
# 這兩個函數的主要差異是什麼？

# %% [markdown]
# **Exercise 2.** Repeat the same scatter plot but using the [digits dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) instead.
#
# **練習 2.** 重複相同的散佈圖，但使用 [digits 資料集](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html)。

# %%
# B11323225 廖宜翔
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA

X, y = load_digits(return_X_y=True)

pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y,
            edgecolor='none', alpha=0.7, cmap='nipy_spectral')

plt.colorbar(scatter, label='Digit Value')
plt.title('Digits Dataset Visualization (using PCA to 2D)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True, linestyle=':', alpha=0.5)

plt.show()

# %% [markdown]
# Are pixel values good features for classifying samples?
#
# 像素值是用於樣本分類的良好特徵嗎？

# %% [markdown]
# ## Going further
#
# *  Official [tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html)
# * [Tutorial](https://www.youtube.com/watch?v=qErBw-R2Ybk) on Youtube
